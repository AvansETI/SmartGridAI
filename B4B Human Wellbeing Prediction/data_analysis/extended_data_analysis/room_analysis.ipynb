# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
df = pd.read_csv('../../datasets/dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399877 entries, 0 to 399876
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   399877 non-null  int64
#  1   original_entry_id            399877 non-null  int64
#  2   node_id                      399877 non-null  int64
#  3   room                         399877 non-null  object
#  4   datetime                     399877 non-null  object
#  5   hour                         399877 non-null  int64
#  6   minute                       399877 non-null  int64
#  7   second                       399877 non-null  int64
#  8   relative_time                399877 non-null  int64
#  9   temperature                  399877 non-null  float64
#  10  mean_temp_day                399877 non-null  float64
#  11  heatindex                    399877 non-null  float64
#  12  relative_humidity            399877 non-null  float64
#  13  light_sensor_one_wavelength  399877 non-null  float64
#  14  light_sensor_two_wavelength  399877 non-null  float64
#  15  number_occupants             399877 non-null  int64
#  16  activity_occupants           399877 non-null  int64
#  17  door_state                   399877 non-null  int64
#  18  window_state                 399877 non-null  int64
#  19  acceptability_80             399877 non-null  int64
#  20  acceptability_90             399877 non-null  int64
#  21  tmp_cmf                      399877 non-null  float64
#  22  tmp_cmf_80_low               399877 non-null  float64
#  23  tmp_cmf_80_up                399877 non-null  float64
#  24  tmp_cmf_90_low               399877 non-null  float64
#  25  tmp_cmf_90_up                399877 non-null  float64
#  26  year                         399877 non-null  int64
# dtypes: float64(11), int64(14), object(2)
# memory usage: 82.4+ MB

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Univariate Analysis

# %%
df['room'].value_counts(normalize=True)*100
# Out:
# A    49.222386
# B    32.966887
# C    17.810727
# Name: room, dtype: float64

# %%
#desribe a single column in the dataframe
df['room'].describe()
# Out:
# count     399877
# unique         3
# top            A
# freq      196829
# Name: room, dtype: object

# %%
sns.countplot(x='room',data=df)
# Out:
# <AxesSubplot:xlabel='room', ylabel='count'>

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
sns.boxplot(x='room',y='temperature',data=df,ax=ax)
# Out:
# <AxesSubplot:xlabel='room', ylabel='temperature'>
