# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from analysis_utils import analysis_chi_heatmap, analysis_scatter
plt.style.use('dark_background')

# %%
df = pd.read_csv('../../datasets/dataset.csv')

# %%
df.columns
# Out:
# Index(['original_entry_id', 'node_id', 'room', 'datetime', 'hour', 'minute',
#        'second', 'relative_time', 'temperature', 'mean_temp_day', 'heatindex',
#        'relative_humidity', 'light_sensor_one_wavelength',
#        'light_sensor_two_wavelength', 'number_occupants', 'activity_occupants',
#        'door_state', 'window_state', 'acceptability_80', 'acceptability_90',
#        'tmp_cmf', 'tmp_cmf_80_low', 'tmp_cmf_80_up', 'tmp_cmf_90_low',
#        'tmp_cmf_90_up'],
#       dtype='object')

# %% [markdown]
# # Bivariate analysis

# %%
chi_p_values_array = {}

# %% [markdown]
# A higher P value means there is a stronger contingency between the two variables

# %%
df['year'] = pd.DatetimeIndex(df['datetime']).year
df['month'] = pd.DatetimeIndex(df['datetime']).month
df['week'] = pd.DatetimeIndex(df['datetime']).week
df['dayofweek'] = pd.DatetimeIndex(df['datetime']).dayofweek

df['year'] = pd.Categorical(df['year'])
df['month'] = pd.Categorical(df['month'])
df['week'] = pd.Categorical(df['week'])
df['dayofweek'] = pd.Categorical(df['dayofweek'])
# Out:
# C:\Users\m-don\AppData\Local\Temp/ipykernel_26588/3598026493.py:3: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df['week'] = pd.DatetimeIndex(df['datetime']).week

# %%
colums_to_compare = ['year', 'month','week','dayofweek', 'hour', 'number_occupants', 'acceptability_80', 'acceptability_90', 'window_state', 'activity_occupants', 'mean_temp_day']
analysis_chi_heatmap(df,colums_to_compare,'room', chi_p_values_array)

# %% [markdown]
# # Multivariate

# %%
df.columns
# Out:
# Index(['original_entry_id', 'node_id', 'room', 'datetime', 'hour', 'minute',
#        'second', 'relative_time', 'temperature', 'mean_temp_day', 'heatindex',
#        'relative_humidity', 'light_sensor_one_wavelength',
#        'light_sensor_two_wavelength', 'number_occupants', 'activity_occupants',
#        'door_state', 'window_state', 'acceptability_80', 'acceptability_90',
#        'tmp_cmf', 'tmp_cmf_80_low', 'tmp_cmf_80_up', 'tmp_cmf_90_low',
#        'tmp_cmf_90_up', 'room_numerical', 'year', 'month', 'week',
#        'dayofweek'],
#       dtype='object')

# %%
colums_to_compare = ['year', 'month','week','dayofweek', 'hour', 'number_occupants', 'acceptability_80', 'acceptability_90', 'window_state', 'activity_occupants', 'mean_temp_day' ,'temperature' ,'relative_humidity', 'light_sensor_one_wavelength',
            'light_sensor_two_wavelength']
analysis_scatter(df, colums_to_compare,'acceptability_90', 'room')
# Out:
# C:\ProgramData\Anaconda3\envs\SmartGridAI\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
analysis_scatter(df, colums_to_compare,'acceptability_80', 'room')
# Out:
# C:\ProgramData\Anaconda3\envs\SmartGridAI\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
