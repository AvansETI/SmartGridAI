# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
df = pd.read_csv('../../datasets/dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540364 entries, 0 to 540363
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   original_entry_id            540364 non-null  int64
#  1   node_id                      540364 non-null  int64
#  2   room                         540364 non-null  object
#  3   datetime                     540364 non-null  object
#  4   hour                         540364 non-null  int64
#  5   minute                       540364 non-null  int64
#  6   second                       540364 non-null  int64
#  7   relative_time                540364 non-null  int64
#  8   temperature                  540364 non-null  float64
#  9   mean_temp_day                540364 non-null  float64
#  10  heatindex                    540364 non-null  float64
#  11  relative_humidity            540364 non-null  float64
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='room',data=df)
# Out:
# <AxesSubplot:xlabel='room', ylabel='count'>

# %%
#univariate analysis on room
sns.boxplot(x='room',y='temperature',data=df)
# Out:
# <AxesSubplot:xlabel='room', ylabel='temperature'>

# %%
#seaborn on matplotlib fig
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
sns.boxplot(x='room',y='temperature',data=df,ax=ax)
# Out:
# <AxesSubplot:xlabel='room', ylabel='temperature'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(x='room',y='temperature',data=df)
# Out:
# <AxesSubplot:xlabel='room', ylabel='temperature'>
